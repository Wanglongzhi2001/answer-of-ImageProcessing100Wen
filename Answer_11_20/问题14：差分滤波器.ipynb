# %%
import numpy as np
import cv2

# %%
def BGR2GRAY(img):
    b,g,r = cv2.split(img)
    gray = (0.2126 * r + 0.7152 * g + 0.0722 * b).astype('uint8') #一定要变成uint8哦
    return gray

# %%
def diff_filter(img,kernel):
    half_ksize = kernel.shape[0]//2
    img_new=np.copy(img)
    for i in range(half_ksize,img.shape[0]-half_ksize):
        for j in range(half_ksize,img.shape[1]-half_ksize):
            img_new[i,j]=np.sum(kernel*img[i-half_ksize:i+half_ksize+1,j-half_ksize:j+half_ksize+1])
    return img_new.astype(np.uint8)

# %%
kernel_col = np.array([[0,-1,0],[0,1,0],[0,0,0]])
kernel_line = np.array([[0,0,0],[-1,1,0],[0,0,0]])

# %%
img = cv2.imread(r'D:\Program Files (x86)\ImageProcessing100Wen-master\ImageProcessing100Wen-master\Question_01_10\imori.jpg').astype(np.float32)

# %%
#横向
img_gray = BGR2GRAY(img)
output_col = diff_filter(img_gray,kernel_col)
cv2.imshow('2',output_col)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
#纵向
img_gray = BGR2GRAY(img)
output_line = diff_filter(img_gray,kernel_line)
cv2.imshow('2',output_line)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %% [markdown]
# ![image.png](attachment:image.png)
