# %%
import cv2
import numpy as np

# %%
def mean_filter(img,kernel_size):
    img_new=np.copy(img)
    half_ksize = int(kernel_size/2)
    for c in range(3):
        for i in range(half_ksize,img.shape[0]-half_ksize):
            for j in range(half_ksize,img.shape[1]-half_ksize):
                img_new[i,j,c]=np.mean(img[i-half_ksize:i+half_ksize+1,j-half_ksize:j+half_ksize+1,c])
    return img_new.astype(np.uint8)

# %%
img = cv2.imread(r'D:\Program Files (x86)\ImageProcessing100Wen-master\ImageProcessing100Wen-master\Question_01_10\imori.jpg')
cv2.imshow('1',img)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
output = mean_filter(img,3)#核大小为8*8
cv2.imshow('2',output)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %% [markdown]
# ![image.png](attachment:image.png)
