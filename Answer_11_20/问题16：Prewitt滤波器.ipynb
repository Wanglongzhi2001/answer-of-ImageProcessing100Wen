# %%
import cv2
import numpy as np

# %%
def BGR2GRAY(img):
    b,g,r = cv2.split(img)
    gray = (0.2126 * r + 0.7152 * g + 0.0722 * b).astype('uint8') #一定要变成uint8哦
    return gray

# %%
def prewitt_filter(img,kernel):
    half_ksize = kernel.shape[0]//2
    #zero_padding
    pad = half_ksize
    img_pad = np.zeros((img.shape[0] + pad * 2, img.shape[1] + pad * 2), dtype=np.float)
    img_pad[pad: pad + img.shape[0], pad: pad + img.shape[1]] = img.copy().astype(np.float)
    img_new=np.copy(img)
    for i in range(img.shape[0]):
        for j in range(img.shape[1]):
            img_new[i,j]=np.sum(kernel*img_pad[i:i+kernel.shape[0],j:j+kernel.shape[0]])
    #img_new = np.clip(img_new,0,255)
    return img_new.astype(np.uint8)

# %%
kernel_col = np.array([[-1,-1,-1],[0,0,0],[1,1,1]])
kernel_line = np.array([[-1,0,-1],[-1,0,1],[-1,0,1]])
img = cv2.imread(r'D:\Program Files (x86)\ImageProcessing100Wen-master\ImageProcessing100Wen-master\Question_01_10\imori.jpg')

# %%
#横向
img_gray = BGR2GRAY(img)
output_col = prewitt_filter(img_gray,kernel_col)
cv2.imshow('2',output_col)
cv2.waitKey(0)
cv2.destroyAllWindows()
# Out:
# D:\temp\ipykernel_17980\4168807270.py:5: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   img_pad = np.zeros((img.shape[0] + pad * 2, img.shape[1] + pad * 2), dtype=np.float)
# D:\temp\ipykernel_17980\4168807270.py:6: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
# ...

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
#纵向
img_gray = BGR2GRAY(img)
output_line = prewitt_filter(img_gray,kernel_line)
cv2.imshow('2',output_line)
cv2.waitKey(0)
cv2.destroyAllWindows()
# Out:
# D:\temp\ipykernel_17980\4168807270.py:5: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   img_pad = np.zeros((img.shape[0] + pad * 2, img.shape[1] + pad * 2), dtype=np.float)
# D:\temp\ipykernel_17980\4168807270.py:6: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
# ...

# %% [markdown]
# ![image.png](attachment:image.png)
