# %%
import cv2

# %%
def BGR2GRAY(img):
    b = img[:,:,0].copy()
    g = img[:,:,1].copy()
    r = img[:,:,2].copy()
    gray = (0.2126 * r + 0.7152 * g + 0.0722 * b).astype('uint8') #一定要变成uint8哦
    return gray

# %%
def binarization(img, threshold):
    output = 255 * (img >= threshold)
    return output.astype('uint8') #一定要变成uint8哦

# %%
img = cv2.imread(r'D:\Program Files (x86)\ImageProcessing100Wen-master\ImageProcessing100Wen-master\assets\imori.jpg')
cv2.imshow('1',img)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
img_gray = BGR2GRAY(img)
img_bina = binarization(img_gray, 128)

# %%
cv2.imshow('2',img_bina)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %% [markdown]
# ![image.png](attachment:image.png)
